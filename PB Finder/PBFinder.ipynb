# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import scipy

def nicePar(score,par):
    if(score < par):
        return str(score-par)
    elif(score > par):
        return '+' + str(score - par)
    else:
        return 'E'

# %%
class Scorecard:
    def __init__(self, players, scores, course, layout, par):
        self.players = players 
        self.scores = scores
        self.course = course
        self.layout = layout
        self.par = par
    
    def __str__(self):
        return str(self.players) +'\n'+ str(self.scores)+'\n' + str(self.course)+'\n'+ str(self.layout)+'\n'+ str(self.par)+'\n'
    
    def score(self,name):
        return self.scores[self.players.index(name)]
    
    def sortOrder(sc):
        return sc.course + sc.layout

# %%
class Player:
    def __init__(self, name):
        self.scorecards = [] 
        self.name = name
        self.PBs = []
        
    def addScorecard(self,scorecard):
        self.scorecards.append(scorecard)
        self.updatePBs(scorecard)
        return
    
    
    def updatePBs(self,scorecard):
        index = -1
        for i in range(len(self.PBs)):
            if self.PBs[i].layout == scorecard.layout and self.PBs[i].course == scorecard.course:
                index = i
        
        if index == -1:
            self.PBs.append(scorecard)
            self.PBs.sort(key = Scorecard.sortOrder)
            return
        
        if scorecard.score(self.name) <= self.PBs[index].score(self.name):
            self.PBs[index] = scorecard
            self.PBs.sort(key = Scorecard.sortOrder)
            return
        
        
        return
    
    def __str__(self):
        s = self.name + '\'s Stats:\n'
        s = s + ' PBs:\n'
        for i in self.PBs:
            s = s + '  Course: ' + i.course +'  Layout: ' + i.layout + '  Score: ' + nicePar(i.score(self.name),i.par) + '(' + str(i.score(self.name)) + ')' '\n'
        return(s)

# %%
class Club:
    def __init__(self,clubNames):
        self.clubPlayers = []
        self.clubNames = clubNames
        
    def addClubScorecard(self,scorecard):   
        for p in scorecard.players:
            if(not self.isPlayer(p)):
                self.addPlayer(p)
                
            if self.isValidClubScorecard(scorecard.players):
                self.addScorecardToPlayer(scorecard,p)
                
        return 
    def isValidClubScorecard(self,players):
        if len(players) < 2:
            return False
        count = 0
        for i in players:
            if i in self.clubNames:
                count = count + 1
        return count > 1
        
    def addPlayer(self,name):
        if name in self.clubNames:
            self.clubPlayers.append(Player(name))
        return
    
    def addScorecardToPlayer(self,scorecard,name):
        if name in self.clubNames:
            p = next((x for x in self.clubPlayers if x.name == name), None)
            p.addScorecard(scorecard)
        return
        
    def isPlayer(self,name):
        return name in [i.name for i in self.clubPlayers]
    
    def printPlayers(self):
        for i in self.clubPlayers:
            print(i)
        
    def addCSV(self,filename):
        csvfile = open(filename, newline='') 
        read = csv.reader(csvfile, delimiter=',', quotechar='|')
        next(read)
        data = np.array(list(read))
        
        i = 0
        while i < data.shape[0]:                       
            players = []
            scores = []
            course = data[i,1]
            layout = data[i,2]
            par = data[i,4].astype("int")
            
            i = i + 1
            
            while i < data.shape[0] and data[i,0] != 'Par':
                players.append(data[i,0])
                scores.append(data[i,4].astype("int"))
                i = i + 1
            
            sc = Scorecard(players,scores,course,layout,par)
            self.addClubScorecard(Scorecard(players,scores,course,layout,par))

# %%
c = Club(['Justin Mucelli', 'Rob', 'Jake VDL','Surge', 'Adam Gault', 'Eric Bossenbroek','Skye',
          'Neel', 'Nick','James','Nic Fostini ','Cole', 'Adam','Aiden Glennon', 'Jpark17','Casey Koenig',
          'Rowan', 'Robert Dabney','Ethan','Thomas Byrne ','Eric','Trevor P','Zac Montrief','Andrewbullen','Aryan','Bud','Daniel Setareh'])
c.addCSV('./data/JustinMucelliJan82023.csv')
c.addCSV('./data/FlexDaddyRobJanuary112023.csv')
c.printPlayers()
# Out:
# Justin Mucelli's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: -6(53)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Blue Baskets  Score: -1(64)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Silver Baskets  Score: +1(58)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Blue Baskets  Score: +5(65)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Silver Baskets  Score: -9(45)
#   Course: Burbine Forest DGC  Layout: Main  Score: -2(55)
#   Course: Burbine Forest DGC  Layout: Red Shorts Tees  Score: -5(52)
#   Course: CTK pitch And Putt  Layout: Custom Layout  Score: -4(50)
#   Course: Campgaw Reservation  Layout: Black Tees  Score: -4(66)
#   Course: Campgaw Reservation  Layout: Green  Score: +5(59)
#   Course: Central Park  Layout: Main Blue 18  Score: -3(55)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: -4(53)
#   Course: Central Park  Layout: Main White Tees 18  Score: -3(53)
#   Course: Christ the King Center   Layout: Blue Tees  Score: -4(59)
#   Course: Christ the King Center   Layout: Red Tees  Score: E(58)
#   Course: Colonial Acres Park  Layout: Reds + Whites  Score: -8(46)
#   Course: Cranbury Park DGC  Layout: Red Course  Score: +16(73)
#   Course: FDR State Park  Layout: Long Baskets (White)  Score: -5(57)
#   Course: Hyzer Creek  Layout: Main  Score: -8(55)
#   Course: Joralemon Park  Layout: All Of J  Score: E(127)
#   Course: Joralemon Park  Layout: J East 18  Score: +1(59)
#   Course: Joralemon Park  Layout: J North 18  Score: +10(72)
#   Course: Joralemon Park  Layout: J South 18  Score: E(59)
#   Course: Joralemon Park  Layout: J West 18  Score: -7(50)
#   Course: Joralemon Park  Layout: J27  Score: +2(88)
#   Course: Joralemon Park  Layout: J36  Score: +8(129)
#   Course: Maple Hill  Layout: Diamonds  Score: +9(69)
#   Course: Maple Hill  Layout: Maple Hill Blues  Score: +6(63)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +25(85)
#   Course: Mine Kill State Park  Layout: 2021 MKDGC Am Layout  Score: +8(67)
#   Course: Mine Kill State Park  Layout: 2022 MKDGC Orange Tee Layout  Score: +10(72)
#   Course: Mine Kill State Park  Layout: Best-of  Score: +7(66)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: -29(26)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +3(65)
#   Course: Minekill Best Of  Layout: Custom  Score: +1(60)
#   Course: Minekill Best-Of  Layout: Custom  Score: +6(65)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: -3(25)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -11(45)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: -2(53)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: -2(53)
#   Course: Shenantaha Creek   Layout: Original 18  Score: -5(51)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: -1(55)
#   Course: Stonykill 8Ball  Layout: Custom  Score: +12(70)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: -5(53)
#   Course: Stonykill Ript Revenge  Layout: Custom  Score: +8(65)
#   Course: Thacher State Park  Layout: 18 holes  Score: -10(51)
#   Course: The Oasis  Layout: Red  Score: +6(60)
#   Course: Wilcox Blues North  Layout: Custom Layout  Score: -1(64)
#   Course: Wilcox Blues South   Layout: Custom Layout  Score: -1(63)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Blue  Score: +5(76)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Red Tees  Score: +3(61)
#   Course: Wilcox Memorial Park  Layout: Red 27  Score: -7(79)
#   Course: Wilcox South Blues  Layout: Custom Layout  Score: -3(61)
#   Course: Willow Park  Layout: 18 hole layout  Score: -5(52)
#   Course: Windsor Lake Disc Golf Course   Layout: Blue Long Tees  Score: E(58)
#
# Rob's Stats:
#  PBs:
#   Course: Beacon Glades  Layout: BG 18 Summer  Score: +9(64)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Blue Baskets  Score: +4(69)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Silver Baskets  Score: +12(69)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Blue Baskets  Score: +20(80)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Silver Baskets  Score: -4(50)
#   Course: Browns Point/Buzzy's Creek  Layout: Main  Score: +7(61)
#   Course: Burbine Forest DGC  Layout: Main  Score: +13(70)
#   Course: Burbine Forest DGC  Layout: Red Shorts Tees  Score: -5(52)
#   Course: Campgaw Reservation  Layout: Black Tees  Score: +6(76)
#   Course: Campgaw Reservation  Layout: Green  Score: +5(59)
#   Course: Campgaw Reservation  Layout: Main  Score: +4(58)
#   Course: Central Park  Layout: Main Blue 18  Score: +5(63)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +6(63)
#   Course: Central Park  Layout: Main White 18  Score: +5(63)
#   Course: Central Park  Layout: Main White Tees 18  Score: -1(55)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +9(72)
#   Course: Christ the King Center   Layout: Red Tees  Score: E(58)
#   Course: FDR State Park  Layout: Short Baskets (Yellow)  Score: +11(69)
#   Course: Hyzer Creek  Layout: Main  Score: +6(69)
#   Course: Joralemon Park  Layout: All Of J  Score: +27(154)
#   Course: Joralemon Park  Layout: J North 18  Score: +6(68)
#   Course: Joralemon Park  Layout: J South 18  Score: +8(67)
#   Course: Joralemon Park  Layout: J West 18  Score: +7(64)
#   Course: Joralemon Park  Layout: J36  Score: +36(157)
#   Course: Leonard Park  Layout: Short Baskets  Score: +10(65)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: -27(28)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +17(79)
#   Course: Minekill Best Of  Layout: Custom  Score: +11(70)
#   Course: Minekill Best-Of  Layout: Custom  Score: +12(71)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: -1(27)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -3(53)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: -1(54)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: -1(54)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +4(60)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +9(65)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +6(64)
#   Course: Thacher State Park  Layout: 18 holes  Score: -1(60)
#   Course: The Oasis  Layout: Red  Score: +6(60)
#   Course: Willow Park  Layout: 18 hole layout  Score: +3(60)
#   Course: Windsor Lake Disc Golf Course   Layout: Blue Long Tees  Score: +2(60)
#
# Jake VDL's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: +1(60)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Blue Baskets  Score: +2(67)
#   Course: Brakewell Steel/Warwick  Layout: Blue Tees - Silver Baskets  Score: +5(62)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Silver Baskets  Score: -2(52)
#   Course: Burbine Forest DGC  Layout: Main  Score: -1(56)
#   Course: CTK pitch And Putt  Layout: Custom Layout  Score: -12(42)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: -3(54)
#   Course: Central Park  Layout: Main White Tees 18  Score: -9(47)
#   Course: Christ the King Center   Layout: Blue Tees  Score: -3(60)
#   Course: Colonial Acres Park  Layout: Reds + Whites  Score: -10(44)
#   Course: FDR State Park  Layout: Long Baskets (White)  Score: -1(61)
#   Course: Hyzer Creek  Layout: Main  Score: -8(55)
#   Course: Joralemon Park  Layout: J East 18  Score: -1(57)
#   Course: Joralemon Park  Layout: J North 18  Score: +1(63)
#   Course: Joralemon Park  Layout: J South 18  Score: E(59)
#   Course: Joralemon Park  Layout: J West 18  Score: +1(58)
#   Course: Joralemon Park  Layout: J27  Score: +1(87)
#   Course: Maple Hill  Layout: Diamonds  Score: +8(68)
#   Course: Maple Hill  Layout: Maple Hill Blues  Score: +3(60)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +20(80)
#   Course: Mine Kill State Park  Layout: 2021 MKDGC Am Layout  Score: +4(63)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: -2(53)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +21(83)
#   Course: Minekill Best Of  Layout: Custom  Score: +2(61)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: -4(24)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -5(51)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: -1(54)
#   Course: Shenantaha Creek   Layout: Original 18  Score: -3(53)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: -1(55)
#   Course: Stonykill 8Ball  Layout: Custom  Score: +7(65)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: -4(54)
#   Course: Stonykill Ript Revenge  Layout: Custom  Score: +21(78)
#   Course: Thacher State Park  Layout: 18 holes  Score: -10(51)
#   Course: Wilcox Blues North  Layout: Custom Layout  Score: +8(73)
#   Course: Wilcox Blues South   Layout: Custom Layout  Score: +2(66)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Blue  Score: +7(78)
#   Course: Wilcox Memorial Park  Layout: Red 27  Score: -11(75)
#   Course: Willow Park  Layout: 18 hole layout  Score: -3(54)
#   Course: Windsor Lake Disc Golf Course   Layout: Blue Long Tees  Score: -3(55)
#
# Surge's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue 18  Score: +8(66)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +8(65)
#   Course: Central Park  Layout: Main White 18  Score: +6(64)
#   Course: Central Park  Layout: Main White Tees 18  Score: -4(52)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +26(89)
#   Course: Christ the King Center   Layout: Red Tees  Score: +19(76)
#   Course: Hyzer Creek  Layout: Main  Score: +9(72)
#   Course: Joralemon Park  Layout: J36  Score: +35(156)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: E(28)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: E(56)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: +12(67)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +2(57)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +4(60)
#   Course: Stonykill 8Ball  Layout: Custom  Score: +21(79)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +10(68)
#   Course: Stonykill Ript Revenge  Layout: Custom  Score: +22(79)
#   Course: Thacher State Park  Layout: 18 holes  Score: -1(60)
#   Course: Willow Park  Layout: 18 hole layout  Score: +5(62)
#
# Adam Gault's Stats:
#  PBs:
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +4(60)
#
# Eric Bossenbroek's Stats:
#  PBs:
#   Course: Burbine Forest DGC  Layout: Main  Score: +14(71)
#   Course: Central Park  Layout: Main Blue 18  Score: +24(82)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +13(70)
#   Course: Central Park  Layout: Main White Tees 18  Score: +8(64)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +15(78)
#   Course: Christ the King Center   Layout: Red Tees  Score: +8(66)
#   Course: Joralemon Park  Layout: J North 18  Score: +20(82)
#   Course: Joralemon Park  Layout: J West 18  Score: +14(71)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +1(57)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +6(61)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +10(66)
#   Course: Thacher State Park  Layout: 18 holes  Score: +5(66)
#   Course: Willow Park  Layout: 18 hole layout  Score: +14(71)
#
# Skye's Stats:
#  PBs:
#   Course: Central Park  Layout: Main White Tees 18  Score: +25(81)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +19(75)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +30(85)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +31(87)
#   Course: Willow Park  Layout: 18 hole layout  Score: +34(91)
#
# Neel's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue 18  Score: +61(119)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: +48(103)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +44(102)
#   Course: Willow Park  Layout: 18 hole layout  Score: +45(102)
#
# Nick's Stats:
#  PBs:
#   Course: Burbine Forest DGC  Layout: Main  Score: +30(87)
#   Course: Central Park  Layout: Main White Tees 18  Score: +12(68)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +10(73)
#   Course: Cranbury Park DGC  Layout: Red Course  Score: +60(117)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +11(66)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +16(72)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +20(78)
#   Course: Willow Park  Layout: 18 hole layout  Score: +19(76)
#
# James's Stats:
#  PBs:
#   Course: Burbine Forest DGC  Layout: Main  Score: +20(77)
#   Course: Joralemon Park  Layout: J South 18  Score: +31(90)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +28(84)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +18(73)
#   Course: Willow Park  Layout: 18 hole layout  Score: +15(72)
#
# Nic Fostini 's Stats:
#  PBs:
#   Course: Joralemon Park  Layout: J South 18  Score: +20(79)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +8(64)
#
# Cole's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: +29(88)
#   Course: Burbine Forest DGC  Layout: Main  Score: +3(60)
#   Course: Burbine Forest DGC  Layout: Red Shorts Tees  Score: -3(54)
#   Course: Central Park  Layout: Main Blue 18  Score: +12(70)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +8(65)
#   Course: Central Park  Layout: Main White 18  Score: +1(59)
#   Course: Central Park  Layout: Main White Tees 18  Score: +5(61)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +6(69)
#   Course: Christ the King Center   Layout: Red Tees  Score: E(58)
#   Course: Hyzer Creek  Layout: Main  Score: -3(60)
#   Course: Joralemon Park  Layout: All Of J  Score: +18(145)
#   Course: Joralemon Park  Layout: J East 18  Score: +13(71)
#   Course: Joralemon Park  Layout: J North 18  Score: +37(99)
#   Course: Joralemon Park  Layout: J South 18  Score: +17(76)
#   Course: Joralemon Park  Layout: J West 18  Score: +4(61)
#   Course: Joralemon Park  Layout: J27  Score: +29(115)
#   Course: Joralemon Park  Layout: J36  Score: +21(142)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +16(78)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -5(51)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: -2(53)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +3(59)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +3(61)
#   Course: Thacher State Park  Layout: 18 holes  Score: -6(55)
#   Course: Wilcox Blues North  Layout: Custom Layout  Score: +13(78)
#   Course: Wilcox Blues South   Layout: Custom Layout  Score: +6(70)
#   Course: Wilcox South Blues  Layout: Custom Layout  Score: +19(83)
#   Course: Willow Park  Layout: 18 hole layout  Score: +5(62)
#
# Adam's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue 18  Score: +17(75)
#   Course: Central Park  Layout: Main White Tees 18  Score: +14(70)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +20(83)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +9(65)
#
# Aiden Glennon's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: +3(62)
#   Course: Burbine Forest DGC  Layout: Main  Score: -5(52)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +3(66)
#   Course: Hyzer Creek  Layout: Main  Score: -11(52)
#   Course: Joralemon Park  Layout: All Of J  Score: +11(138)
#   Course: Joralemon Park  Layout: J North 18  Score: +7(69)
#   Course: Joralemon Park  Layout: J South 18  Score: +2(61)
#   Course: Joralemon Park  Layout: J West 18  Score: +1(58)
#   Course: Maple Hill  Layout: Diamonds  Score: +4(64)
#   Course: Maple Hill  Layout: Maple Hill Blues  Score: +3(60)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +24(84)
#   Course: Mine Kill State Park  Layout: Best-of  Score: E(59)
#   Course: Minekill Best Of  Layout: Custom  Score: +1(60)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -4(52)
#   Course: Shenantaha Creek   Layout: Original 18  Score: E(56)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +4(60)
#   Course: Stonykill 8Ball  Layout: Custom  Score: +6(64)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +1(59)
#   Course: Stonykill Ript Revenge  Layout: Custom  Score: +7(64)
#
# Jpark17's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: +7(66)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +1(58)
#   Course: Central Park  Layout: Main White Tees 18  Score: -3(53)
#   Course: Christ the King Center   Layout: Blue Tees  Score: E(63)
#   Course: Hyzer Creek  Layout: Main  Score: -4(59)
#   Course: Joralemon Park  Layout: All Of J  Score: +21(148)
#   Course: Joralemon Park  Layout: J West 18  Score: -3(54)
#   Course: Joralemon Park  Layout: J27  Score: +8(94)
#   Course: Maple Hill  Layout: Diamonds  Score: +3(63)
#   Course: Maple Hill  Layout: Maple Hill Blues  Score: +4(61)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +29(89)
#   Course: Mine Kill State Park  Layout: 2021 MKDGC Am Layout  Score: +6(65)
#   Course: Mine Kill State Park  Layout: Best-of  Score: +6(65)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: -2(53)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +8(70)
#   Course: Minekill Best Of  Layout: Custom  Score: +1(60)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: -1(27)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: E(55)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +1(56)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +3(59)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +8(64)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +5(63)
#   Course: Thacher State Park  Layout: 18 holes  Score: -10(51)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Blue  Score: +7(78)
#   Course: Wilcox Memorial Park  Layout: Red 27  Score: E(86)
#   Course: Willow Park  Layout: 18 hole layout  Score: -6(51)
#
# Rowan's Stats:
#  PBs:
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +21(76)
#
# Robert Dabney's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +20(77)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +9(72)
#   Course: Christ the King Center   Layout: Red Tees  Score: E(58)
#   Course: Colonial Acres Park  Layout: Reds + Whites  Score: E(54)
#   Course: Joralemon Park  Layout: J North 18  Score: +16(78)
#   Course: Joralemon Park  Layout: J West 18  Score: +12(69)
#   Course: Joralemon Park  Layout: J36  Score: +25(146)
#   Course: Mine Kill State Park  Layout: 2022 MKDGC Orange Tee Layout  Score: +13(75)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: +8(63)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -1(54)
#   Course: Saratoga Spa State Park  Layout: Main A then B  Score: +5(60)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +5(61)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +18(74)
#
# Ethan's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +15(72)
#   Course: Central Park  Layout: Main White Tees 18  Score: +11(67)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +12(75)
#   Course: Joralemon Park  Layout: J North 18  Score: +19(81)
#   Course: Joralemon Park  Layout: J West 18  Score: +18(75)
#   Course: Joralemon Park  Layout: J27  Score: +31(117)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +25(85)
#   Course: Mine Kill State Park  Layout: Orange - Orange  Score: +20(82)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +6(62)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: +13(68)
#
# Thomas Byrne 's Stats:
#  PBs:
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +18(75)
#   Course: Central Park  Layout: Main White Tees 18  Score: +7(63)
#   Course: Christ the King Center   Layout: Blue Tees  Score: +31(94)
#   Course: Joralemon Park  Layout: J South 18  Score: +13(72)
#   Course: Joralemon Park  Layout: J West 18  Score: +16(73)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +10(66)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: +14(69)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +14(70)
#   Course: Stonykill 8Ball  Layout: Custom  Score: +18(76)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +13(71)
#   Course: Stonykill Ript Revenge  Layout: Custom  Score: +20(77)
#   Course: Thacher State Park  Layout: 18 holes  Score: E(61)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Red Tees  Score: +24(82)
#   Course: Wilcox Memorial Park  Layout: Red 27  Score: +21(107)
#
# Casey Koenig's Stats:
#  PBs:
#   Course: Blatnick Park  Layout: Blues  Score: +2(61)
#   Course: Central Park  Layout: Main Blue Tees 18  Score: +4(61)
#   Course: Central Park  Layout: Main White Tees 18  Score: -3(53)
#   Course: Christ the King Center   Layout: Blue Tees  Score: -4(59)
#   Course: Joralemon Park  Layout: J East 18  Score: -1(57)
#   Course: Joralemon Park  Layout: J South 18  Score: +7(66)
#   Course: Joralemon Park  Layout: J West 18  Score: +8(65)
#   Course: Joralemon Park  Layout: J27  Score: +13(99)
#   Course: Mine Kill State Park  Layout: 2021 MKDGC Am Layout  Score: E(59)
#   Course: Mine Kill State Park  Layout: Best-of  Score: +10(69)
#   Course: Mine Kill State Park  Layout: Green - Green  Score: E(55)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: +1(29)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -2(54)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: +5(60)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +5(61)
#   Course: Stephen P Wallace Park  Layout: Blue Tees  Score: +9(65)
#   Course: Thacher State Park  Layout: 18 holes  Score: -9(52)
#   Course: Willow Park  Layout: 18 hole layout  Score: -2(55)
#
# Zac Montrief's Stats:
#  PBs:
#   Course: Prospect Park  Layout: Prospect Park 18  Score: -2(54)
#
# Eric's Stats:
#  PBs:
#   Course: Burbine Forest DGC  Layout: Main  Score: +7(64)
#
# Trevor P's Stats:
#  PBs:
#   Course: Christ the King Center   Layout: Blue Tees  Score: +13(76)
#   Course: Christ the King Center   Layout: Red Tees  Score: +10(67)
#   Course: Joralemon Park  Layout: J East 18  Score: +13(71)
#   Course: Joralemon Park  Layout: J North 18  Score: +19(81)
#   Course: Joralemon Park  Layout: J West 18  Score: +10(67)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +2(58)
#   Course: Shenantaha Creek   Layout: Original 18  Score: +16(72)
#   Course: Stonykill Disc Golf Course  Layout: Main  Score: +11(69)
#   Course: Thacher State Park  Layout: 18 holes  Score: +7(68)
#   Course: Wilcox Memorial Park  Layout: Main 18 - Red Tees  Score: +16(74)
#   Course: Wilcox Memorial Park  Layout: Red 27  Score: +29(115)
#
# Andrewbullen's Stats:
#  PBs:
#   Course: Prospect Park  Layout: Prospect Park 18  Score: E(56)
#
# Daniel Setareh's Stats:
#  PBs:
#   Course: Joralemon Park  Layout: J East 18  Score: +29(87)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +22(78)
#
# Bud's Stats:
#  PBs:
#   Course: Campgaw Reservation  Layout: Green  Score: -3(51)
#   Course: Maple Hill  Layout: Maple Hill Golds  Score: +23(83)
#   Course: Mine Kill State Park  Layout: Best-of  Score: +6(65)
#
# Aryan's Stats:
#  PBs:
#   Course: Beacon Glades  Layout: BG 18 Summer  Score: +22(77)
#   Course: Brakewell Steel/Warwick  Layout: Silver Tees - Silver Baskets  Score: +14(68)
#   Course: Browns Point/Buzzy's Creek  Layout: Main  Score: +11(65)
#   Course: Campgaw Reservation  Layout: Green  Score: +17(71)
#   Course: Campgaw Reservation  Layout: Main  Score: +20(74)
#   Course: FDR State Park  Layout: Short Baskets (Yellow)  Score: +21(79)
#   Course: Leonard Park  Layout: Short Baskets  Score: +16(71)
#   Course: Prospect Park  Layout: Mount Ida Original 9  Score: +4(32)
#   Course: Prospect Park  Layout: Prospect Park 18  Score: +9(65)
#   Course: Saratoga Spa State Park  Layout: A Front B Back  Score: +10(65)
